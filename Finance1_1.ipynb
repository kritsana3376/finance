# %%
# !pip install yfinance
import pandas as pd
from pandas_datareader import data as pdr
import fix_yahoo_finance
import yfinance as yf
import datetime as dt
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 62 kB 735 kB/s
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ...

# %%
MORE_BK = yf.download("MORE.BK", "2022-01-01","2022-12-14")
MORE_BK.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#             Open  High   Low  Close  Adj Close    Volume
# Date
# 2022-01-04  1.80  1.85  1.76   1.76       1.76  67314000
# 2022-01-05  1.76  1.78  1.74   1.78       1.78  38847300
# 2022-01-06  1.78  1.79  1.75   1.76       1.76  22091800
# 2022-01-07  1.76  1.76  1.74   1.76       1.76  27048600
# 2022-01-10  1.76  1.76  1.67   1.67       1.67  64662300

# %%
plt.plot(MORE_BK["Adj Close"])
plt.grid()

# %%
daily_return = MORE_BK["Close"].pct_change(1)

# %%
plt.figure(figsize=(15,10))
plt.plot(daily_return)
plt.xlabel("Data")
plt.ylabel("Return")
plt.title("MORE Dialy Return from 2022")
plt.grid()

# %%
MORE_TICKER = yf.Ticker("MORE.BK")
hist = MORE_TICKER.history(period="max")
MORE_TICKER.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 2013-04-17 00:00:00+07:00   0.000711         1.125
# 2014-04-29 00:00:00+07:00   0.004000         0.000
# 2015-02-03 00:00:00+07:00   0.000000         5.000

# %%
hist_1 = MORE_TICKER.history(period="max",interval="1m")
hist_1
# Out:
#                            Open  High   Low  Close  Volume  Dividends  \
# Datetime
# 2022-12-07 16:14:00+07:00  0.43  0.43  0.43   0.43       0          0
# 2022-12-07 16:15:00+07:00  0.43  0.43  0.43   0.43  194500          0
# 2022-12-07 16:16:00+07:00  0.43  0.43  0.43   0.43  472700          0
# 2022-12-07 16:17:00+07:00  0.43  0.43  0.43   0.43  162600          0
# 2022-12-07 16:18:00+07:00  0.43  0.43  0.43   0.43  155000          0
# ...                         ...   ...   ...    ...     ...        ...
# 2022-12-14 15:38:00+07:00  0.42  0.42  0.42   0.42    2100          0
# 2022-12-14 15:39:00+07:00  0.42  0.42  0.42   0.42    1200          0
# 2022-12-14 15:41:00+07:00  0.42  0.42  0.42   0.42   43100          0
# 2022-12-14 15:42:00+07:00  0.42  0.42  0.42   0.42   18600          0
# 2022-12-14 15:43:21+07:00  0.42  0.42  0.42   0.42       0          0
#
#                            Stock Splits
# Datetime
# 2022-12-07 16:14:00+07:00             0
# ...

# %%
hist_1 = MORE_TICKER.history(period="max",interval="2m")
hist_1
# Out:
# - MORE.BK: 2m data not available for startTime=1356058800 and endTime=1671009214. The requested range must be within the last 60 days.
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
hist_1 = MORE_TICKER.history(period="max",interval="30m")
hist_1
# Out:
# - MORE.BK: 15m data not available for startTime=1356058800 and endTime=1671009220. The requested range must be within the last 60 days.
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
hist_1 = MORE_TICKER.history(period="max",interval="1hr")
hist_1
# Out:
# - MORE.BK: Invalid input - interval=1hr is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
hist_1 = MORE_TICKER.history(period="max",interval="1d")
hist_1
# Out:
#                                Open      High       Low     Close      Volume  \
# Date
# 2012-12-21 00:00:00+07:00  0.616685  0.665740  0.543104  0.543104  2232903420
# 2012-12-24 00:00:00+07:00  0.557119  0.581647  0.529087  0.567631   589715460
# 2012-12-25 00:00:00+07:00  0.557119  0.564127  0.536096  0.536096   165938062
# 2012-12-26 00:00:00+07:00  0.539600  0.557119  0.539600  0.543104    63107437
# 2012-12-27 00:00:00+07:00  0.546607  0.550112  0.539600  0.543104    48093750
# ...                             ...       ...       ...       ...         ...
# 2022-12-07 00:00:00+07:00  0.430000  0.460000  0.420000  0.430000    84379300
# 2022-12-08 00:00:00+07:00  0.430000  0.440000  0.410000  0.430000    36729200
# 2022-12-09 00:00:00+07:00  0.420000  0.430000  0.410000  0.420000    36006800
# 2022-12-13 00:00:00+07:00  0.420000  0.420000  0.390000  0.400000    48667900
# 2022-12-14 00:00:00+07:00  0.410000  0.440000  0.410000  0.420000    62546004
#
# ...

# %%
hist_1 = MORE_TICKER.history(period="max",interval="1wk")
hist_1
# Out:
#                                Open      High       Low     Close  \
# Date
# 2012-12-17 00:00:00+07:00  0.616685  0.665740  0.543104  0.543104
# 2012-12-24 00:00:00+07:00  0.557119  0.581647  0.529088  0.536096
# 2012-12-31 00:00:00+07:00  0.536096  0.550112  0.515072  0.550112
# 2013-01-07 00:00:00+07:00  0.546607  0.550112  0.518576  0.532592
# 2013-01-14 00:00:00+07:00  0.525584  0.567631  0.518576  0.567631
# ...                             ...       ...       ...       ...
# 2022-11-21 00:00:00+07:00  0.960000  0.960000  0.340000  0.580000
# 2022-11-28 00:00:00+07:00  0.560000  0.590000  0.390000  0.460000
# 2022-12-05 00:00:00+07:00  0.450000  0.460000  0.410000  0.420000
# 2022-12-12 00:00:00+07:00  0.420000  0.420000  0.390000  0.400000
# 2022-12-14 00:00:00+07:00  0.410000  0.440000  0.410000  0.420000
#
#                                  Volume  Dividends  Stock Splits
# Date
# 2012-12-17 00:00:00+07:00  2.232903e+09        0.0           0.0
# ...
